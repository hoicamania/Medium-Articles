# %%
#Import HDAMA file
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import seaborn as sns
csv = pd.read_csv('C:/Users/dhoic/Desktop/breast-cancer-wisconsin.csv')
df = pd.DataFrame(csv)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 11 columns):
# CodeNumber                  698 non-null int64
# ClumpThickness              698 non-null int64
# UniformityCellSize          698 non-null int64
# UniformityCellShape         698 non-null int64
# MarginalAdhesion            698 non-null int64
# SingleEpithelialCellSize    698 non-null int64
# BareNuclei                  698 non-null object
# BlandChromatin              698 non-null int64
# NormalNucleoli              698 non-null int64
# Mitoses                     698 non-null int64
# CancerType                  698 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 60.1+ KB

# %%
print(df.shape)
# Out:
# (698, 11)

# %%
print(df['CancerType'].unique())
# Out:
# [2 4]

# %%
print(df.groupby('CancerType').size())
# Out:
# CancerType
# 2    457
# 4    241
# dtype: int64

# %%
#Check for null values
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')
plt.show()

# %%
df.isnull().sum()
# Out:
# CodeNumber                  0
# ClumpThickness              0
# UniformityCellSize          0
# UniformityCellShape         0
# MarginalAdhesion            0
# SingleEpithelialCellSize    0
# BareNuclei                  0
# BlandChromatin              0
# NormalNucleoli              0
# Mitoses                     0
# CancerType                  0
# dtype: int64

# %%
df.describe()
# Out:
#          CodeNumber  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# count  6.980000e+02      698.000000          698.000000           698.000000
# mean   1.071807e+06        4.416905            3.137536             3.210602
# std    6.175323e+05        2.817673            3.052575             2.972867
# min    6.163400e+04        1.000000            1.000000             1.000000
# 25%    8.702582e+05        2.000000            1.000000             1.000000
# 50%    1.171710e+06        4.000000            1.000000             1.000000
# 75%    1.238354e+06        6.000000            5.000000             5.000000
# max    1.345435e+07       10.000000           10.000000            10.000000
#
#        MarginalAdhesion  SingleEpithelialCellSize  BlandChromatin  \
# count        698.000000                698.000000      698.000000
# mean           2.809456                  3.217765        3.438395
# std            2.856606                  2.215408        2.440056
# ...

# %%
df.groupby("ClumpThickness").ClumpThickness.count()
# Out:
# ClumpThickness
# 1     145
# 2      50
# 3     108
# 4      80
# 5     129
# 6      34
# 7      23
# 8      46
# 9      14
# 10     69
# Name: ClumpThickness, dtype: int64

# %%
df.groupby("UniformityCellSize").UniformityCellSize.count()
# Out:
# UniformityCellSize
# 1     383
# 2      45
# 3      52
# 4      40
# 5      30
# 6      27
# 7      19
# 8      29
# 9       6
# 10     67
# Name: UniformityCellSize, dtype: int64

# %%
df.groupby("UniformityCellShape").UniformityCellShape.count()
# Out:
# UniformityCellShape
# 1     352
# 2      59
# 3      56
# 4      44
# 5      34
# 6      30
# 7      30
# 8      28
# 9       7
# 10     58
# Name: UniformityCellShape, dtype: int64

# %%
df.groupby("MarginalAdhesion").MarginalAdhesion.count()
# Out:
# MarginalAdhesion
# 1     406
# 2      58
# 3      58
# 4      33
# 5      23
# 6      22
# 7      13
# 8      25
# 9       5
# 10     55
# Name: MarginalAdhesion, dtype: int64

# %%
df.groupby("SingleEpithelialCellSize").SingleEpithelialCellSize.count()
# Out:
# SingleEpithelialCellSize
# 1      47
# 2     385
# 3      72
# 4      48
# 5      39
# 6      41
# 7      12
# 8      21
# 9       2
# 10     31
# Name: SingleEpithelialCellSize, dtype: int64

# %%
df.groupby("BlandChromatin").BlandChromatin.count()
# Out:
# BlandChromatin
# 1     152
# 2     166
# 3     164
# 4      40
# 5      34
# 6      10
# 7      73
# 8      28
# 9      11
# 10     20
# Name: BlandChromatin, dtype: int64

# %%
df.groupby("BareNuclei").BareNuclei.count()
# Out:
# BareNuclei
# 1     401
# 10    132
# 2      30
# 3      28
# 4      19
# 5      30
# 6       4
# 7       8
# 8      21
# 9       9
# ?      16
# Name: BareNuclei, dtype: int64

# %%
df.groupby("NormalNucleoli").NormalNucleoli.count()
# Out:
# NormalNucleoli
# 1     442
# 2      36
# 3      44
# 4      18
# 5      19
# 6      22
# 7      16
# 8      24
# 9      16
# 10     61
# Name: NormalNucleoli, dtype: int64

# %%
df.groupby("Mitoses").Mitoses.count()
# Out:
# Mitoses
# 1     578
# 2      35
# 3      33
# 4      12
# 5       6
# 6       3
# 7       9
# 8       8
# 10     14
# Name: Mitoses, dtype: int64

# %%
df.groupby("CancerType").CancerType.count()
# Out:
# CancerType
# 2    457
# 4    241
# Name: CancerType, dtype: int64

# %%
df = df[df.BareNuclei != '?']
df.groupby("BareNuclei").BareNuclei.count()
# Out:
# BareNuclei
# 1     401
# 10    132
# 2      30
# 3      28
# 4      19
# 5      30
# 6       4
# 7       8
# 8      21
# 9       9
# Name: BareNuclei, dtype: int64

# %%
#Correlation matrix
k = 10
#number of variables for heatmap
cols = df.corr().nlargest(k, 'CancerType')['CancerType'].index
cm = df[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')
plt.show()

# %%
sns.countplot(df['CancerType'],label="Count")
plt.show()

# %%
Benign = pd.get_dummies(df.CancerType).iloc[:,1:]
df['Malignant'] = Benign
df.Malignant.value_counts()
# Out:
# 0    457
# 1    241
# Name: Malignant, dtype: int64

# %%
df.head()
# Out:
#    CodeNumber  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# 0     1002945               5                   4                    4
# 1     1015425               3                   1                    1
# 2     1016277               6                   8                    8
# 3     1017023               4                   1                    1
# 4     1017122               8                  10                   10
#
#    MarginalAdhesion  SingleEpithelialCellSize BareNuclei  BlandChromatin  \
# 0                 5                         7         10               3
# 1                 1                         2          2               3
# 2                 1                         3          4               3
# 3                 3                         2          1               3
# 4                 8                         7         10               9
#
#    NormalNucleoli  Mitoses  CancerType
# 0               2        1           2
# ...

# %%
df.drop('Malignant', axis=1).plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False, figsize=(9,9), 
                                        title='Box Plot for each input variable')
plt.savefig('Cancer Diagnosis')
plt.show()

# %%
import pylab as pl
df.drop('Malignant' ,axis=1).hist(bins=30, figsize=(9,9))
pl.suptitle("Histogram for each numeric input variable")
plt.savefig('Cancer_hist')
plt.show()

# %%
#Correlation matrix
k = 10
#number of variables for heatmap
cols = df.corr().nlargest(k, 'Malignant')['Malignant'].index
cm = df[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')
plt.show()

# %%
    df = df[df.BareNuclei != '?']
    X = df.drop(['Malignant'], axis=1)
    y = df['Malignant']

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)
X_test = pd.DataFrame(X_test)
y_test = pd.DataFrame(y_test)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train.values.ravel())
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.65
# Accuracy of Logistic regression classifier on test set: 0.64

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, y_train.values.ravel())
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 1.00

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train.values.ravel())
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.73
# Accuracy of K-NN classifier on test set: 0.65

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train.values.ravel())
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train, y_train)))
print('Accuracy of SVM classifier on test set: {:.2f}'
     .format(svm.score(X_test, y_test)))
# Out:
# Accuracy of SVM classifier on training set: 1.00
# Accuracy of SVM classifier on test set: 0.65

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, y_train.values.ravel())
print('Accuracy of LDA classifier on training set: {:.2f}'
     .format(lda.score(X_train, y_train)))
print('Accuracy of LDA classifier on test set: {:.2f}'
     .format(lda.score(X_test, y_test)))
# Out:
# Accuracy of LDA classifier on training set: 0.96
# Accuracy of LDA classifier on test set: 0.97
# C:\Users\dhoic\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train.values.ravel())
print('Accuracy of GNB classifier on training set: {:.2f}'
     .format(gnb.score(X_train, y_train)))
print('Accuracy of GNB classifier on test set: {:.2f}'
     .format(gnb.score(X_test, y_test)))
# Out:
# Accuracy of GNB classifier on training set: 0.85
# Accuracy of GNB classifier on test set: 0.80

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
pred = clf.predict(X_test)
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[90  0]
#  [ 0 47]]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        90
#           1       1.00      1.00      1.00        47
#
# avg / total       1.00      1.00      1.00       137
